# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import robotdatapy as rdp # 1.0.3
import scipy as sp

# plt.style.use('/home/masonbp/computer/python/matplotlib/publication.mplstyle')
SAVE = True
QUICK = False
ADD_ANNOTATIONS = True

# quicker
if QUICK:
    num_pcs = 100
    num_markers = 500
else:
    num_pcs = 3000
    num_markers = 4000

# %%
def get_pc(bag_path, topic, child_frame):
    pcd = rdp.data.PointCloudData.from_bag(
        path=bag_path,
        topic=topic,
    )

    marker_data = rdp.data.GeneralData.from_bag(
        path=bag_path,
        topic="/NX01/actual_traj",
        ros_distro='humble',
        time_tol=30.0,
        causal=False
    )

    pc_frame = pcd.msg_header(pcd.t0).frame_id
    print("pc_frame:", pc_frame)

    pd = rdp.data.PoseData.from_bag_tf(
        bag_path,
        parent_frame="map",
        child_frame=child_frame,
        time_tol=30.0
    )

    # Robust point cloud extraction at pcd.tf
    pc = pcd.pointcloud(pcd.tf).get_xyz()
    # if not isinstance(vecs, np.ndarray) or vecs.ndim != 2 or vecs.shape[0] == 0 or vecs.shape[1] != 3:
    #     print(f"[Warning] Empty or invalid point cloud at t = {pcd.tf}. Skipping transform.")
    #     pc = np.zeros((0, 3))
    # else:
    #     pc = rdp.transform.transform(pd.pose(pcd.tf), vecs)

    return pc, pcd, pd, marker_data

def apply_transform(points):
    T_side_view = rdp.transform.xyz_rpy_to_transform([0., 0., 0.], [-85., -0., 0.], degrees=True) @ \
        rdp.transform.xyz_rpy_to_transform([0., 0., 0.,], [0., 0., 80.], degrees=True)
    # T_side_view = np.eye(4)

    # degrees to rotation matrix
    roll = 180
    pitch = 0
    yaw = 0

    rotation_matrix = sp.spatial.transform.Rotation.from_euler('xyz', [roll, pitch, yaw], degrees=True).as_matrix()
    T_world_cam = np.array([
        [1., 0., 0., 60.,],
        [0., -1., 0., 0.,],
        [0., 0., -1., 175.,],
        [0., 0., 0., 1.,]
    ])

    K = np.array([[300, 0., 0.], [0., 300, 0.], [0., 0., 1.]])

    points_cam = rdp.transform.transform(np.linalg.inv(T_world_cam) @ T_side_view, points)
    points_cam = points_cam[points_cam[:,2] > 0.1]
    points_side_view = rdp.camera.xyz_2_pixel(points_cam, K)
    return points_side_view

def plot_pc(pc, pcd, pd, marker_data, bag_path, figure_name):
    import matplotlib.pyplot as plt
    plt.style.use('dark_background')
    t = np.linspace(pcd.t0, pcd.tf, num_pcs)

    pcs = []
    for ti in t:
        vecs = pcd.pointcloud(ti).get_xyz()
        if vecs.ndim != 2 or vecs.shape[0] == 0 or vecs.shape[1] != 3:
            print(f"[Warning] Skipping invalid point cloud at t = {ti}. Shape = {vecs.shape}")
            continue
        pc = vecs
        # pc = rdp.transform.transform(pd.pose(ti), vecs)
        pcs.append(pc)

    # Create figure and axis
    fig, ax = plt.subplots(figsize=(10, 10), dpi=500)

    if len(pcs) == 0:
        print("[Warning] No valid point clouds found. Skipping point cloud plot.")
        pc = np.zeros((0, 3))  # Fallback
        ax.text(0.5, 0.5, 'No valid point cloud data', transform=ax.transAxes,
                ha='center', va='center', color='white', fontsize=16)
    else:
        pc = np.vstack(pcs)
        ax.plot(pc[:, 0], pc[:, 1], '.', markersize=0.15, alpha=0.2, color='xkcd:white')

        # --- Compute and add a 10 m scale bar ---
        # x_min, x_max = np.min(pc[:, 0]), np.max(pc[:, 0])
        # y_min, y_max = np.min(pc[:, 1]), np.max(pc[:, 1])
        # print("x_min, x_max, y_min, y_max:", x_min, x_max, y_min, y_max)

        # x_pad = 0.05 * (x_max - x_min)
        # y_pad = 0.05 * (y_max - y_min)
        # x_scale_start = x_min + x_pad - 30.0
        # x_scale_end = x_scale_start + 10.0  # 10 meters
        # y_scale = y_max - y_pad + 20.0

        # ax.plot([x_scale_start, x_scale_end], [y_scale, y_scale], color='white', linewidth=1.5)
        # ax.plot([x_scale_start, x_scale_start], [y_scale - 0.5, y_scale + 0.5], color='white', linewidth=0.5)
        # ax.plot([x_scale_end, x_scale_end], [y_scale - 0.5, y_scale + 0.5], color='white', linewidth=0.5)
        # ax.text(x_scale_start, y_scale - 4.5, '10 m', color='white', fontsize=16)

    # --- Plot markers ---
    marker_xyz = []
    marker_colors = []
    for ti in np.linspace(marker_data.t0, marker_data.tf, num_markers):
        position_ros = marker_data.data(ti).pose.position
        color_ros = marker_data.data(ti).color
        mi = np.array([position_ros.x, position_ros.y, position_ros.z])
        marker_xyz.append(rdp.transform.transform(pd.pose(ti), mi))
        marker_colors.append([color_ros.r, color_ros.g, color_ros.b])
    marker_xyz = np.array(marker_xyz)
    marker_colors = np.array(marker_colors)

    for i in range(marker_xyz.shape[0]):
        ax.plot(marker_xyz[i, 0], marker_xyz[i, 1], '.', markersize=1.0, alpha=1.0, color=marker_colors[i])

    # --- Annotations ---
    if ADD_ANNOTATIONS and len(marker_xyz) > 0:
        markersize = 15.0
        bbox_props = dict(facecolor='white', boxstyle='round,pad=0.1')
        ax.plot([marker_xyz[0, 0]], [marker_xyz[0, 1]], '.', markersize=markersize, color='xkcd:red')
        ax.plot([marker_xyz[-1, 0]], [marker_xyz[-1, 1]], '.', markersize=markersize, color='xkcd:blue')
        ax.text(marker_xyz[0, 0] - 30.0, marker_xyz[0, 1] - 1, 'Start', color='red', fontsize=16, bbox=bbox_props)
        ax.text(marker_xyz[-1, 0] + 5.0, marker_xyz[-1, 1] - 1, 'Goal', color='blue', fontsize=16, bbox=bbox_props)

    ax.set_aspect('equal')
    ax.axis('off')

    if SAVE:
        folder_path = bag_path[:bag_path.rfind('/')]
        plt.savefig(folder_path + figure_name, bbox_inches='tight')

    return pc, marker_xyz, marker_colors

def plot_with_angle(pc, marker_xyz, marker_colors, bag_path, figure_name):
    fig, ax = plt.subplots(figsize=(10, 10), dpi=500)

    # Apply side view transform if point cloud is not empty
    if pc.shape[0] > 0:
        pc_side_view = apply_transform(pc)
        ax.plot(pc_side_view[:, 0], -pc_side_view[:, 1], '.', markersize=0.15, alpha=0.2, color='xkcd:white')
    else:
        print("[Warning] No point cloud data for side view. Skipping point cloud plot.")
        ax.text(0.5, 0.5, 'No point cloud', transform=ax.transAxes,
                ha='center', va='center', color='white', fontsize=16)

    # Apply side view transform to marker data if available
    if marker_xyz.shape[0] > 0:
        marker_xyz_side_view = apply_transform(marker_xyz)

        for i in range(marker_xyz_side_view.shape[0]):
            ax.plot(marker_xyz_side_view[i, 0], -marker_xyz_side_view[i, 1], '.',
                    markersize=1.0, alpha=1.0, color=marker_colors[i])

        if ADD_ANNOTATIONS:
            markersize = 10.0
            bbox = dict(facecolor='white', boxstyle='round,pad=0.1')
            # Plot start and goal markers
            ax.plot([marker_xyz_side_view[0, 0]], [-marker_xyz_side_view[0, 1]], '.', markersize=markersize, color='xkcd:red')
            ax.plot([marker_xyz_side_view[-1, 0]], [-marker_xyz_side_view[-1, 1]], '.', markersize=markersize, color='xkcd:blue')
            # Add labels
            ax.text(marker_xyz_side_view[0, 0] - 2, -marker_xyz_side_view[0, 1] + 3,
                    'Start', color='red', fontsize=16, bbox=bbox)
            ax.text(marker_xyz_side_view[-1, 0] - 3, -marker_xyz_side_view[-1, 1] - 5,
                    'Goal', color='blue', fontsize=16, bbox=bbox)
    else:
        print("[Warning] No marker data for side view.")

    ax.set_aspect('equal')
    ax.axis('off')

    if SAVE:
        folder_path = bag_path[:bag_path.rfind('/')]
        plt.savefig(folder_path + figure_name, bbox_inches='tight')

# %%
# plot the point cloud data
# topic = "/NX01/mid360_PointCloud2"
topic = "/NX01/occupancy_grid"
bag_num = "num_1"

bag_path = f"/media/kkondo/kota_elements/dynus/static/hard_forest/unconstrained/bags/dynus/{bag_num}"
pc, pcd, pd, marker_data = get_pc(bag_path, topic, child_frame="NX01/NX01_livox")

paper_path = "/home/kkondo/paper_writing/dynus_paper/dynus_paper/figures/hard_forest/"
pc, marker_xyz, marker_colors = plot_pc(pc, pcd, pd, marker_data, paper_path, f"/static_{bag_num}_overhead_pc.png")
# plot_with_angle(pc, marker_xyz, marker_colors, paper_path, f"/static_{bag_num}_side_view_pc.png")
# Out:
# pc_frame: map
# [Warning] Skipping invalid point cloud at t = 1758736697.6973357. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736697.7282808. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736697.7592256. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736697.7901707. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736697.8211157. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736697.8520606. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736697.8830056. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736697.9139507. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736697.9448957. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736697.9758406. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.0067856. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.0377307. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.0686755. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.0996206. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.1305656. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.1615105. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.1924555. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.2234006. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.2543454. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.2852905. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.3162355. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.3471806. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.3781254. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.4090705. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.4400156. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.4709604. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.5019054. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.5328505. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.5637953. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.5947404. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.6256855. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.6566305. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.6875753. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.7185204. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.7494655. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.7804103. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.8113554. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.8423004. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.8732452. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.9041903. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.9351354. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.9660802. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736698.9970253. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.0279703. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.0589154. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.0898602. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.1208053. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.1517503. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.1826952. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.2136402. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.2445853. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.27553. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.3064752. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.3374202. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.368365. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.39931. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.4302552. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.4612002. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.492145. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.5230901. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.5540352. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.58498. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.615925. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.6468701. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.677815. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.70876. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.739705. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.77065. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.801595. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.83254. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.863485. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.89443. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.925375. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.95632. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736699.9872649. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.01821. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.049155. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.0800998. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.111045. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.14199. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.172935. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.2038798. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.234825. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.26577. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.2967148. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.3276598. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.358605. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.3895497. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.4204948. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.4514399. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.4823847. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.5133297. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.5442748. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.5752199. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.6061647. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.6371098. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.6680548. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.6989996. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.7299447. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.7608898. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.7918346. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.8227797. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.8537247. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.8846695. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.9156146. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.9465597. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736700.9775047. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.0084496. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.0393946. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.0703397. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.1012845. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.1322296. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.1631746. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.1941195. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.2250645. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.2560096. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.2869544. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.3178995. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.3488445. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.3797896. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.4107344. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.4416795. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.4726245. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.5035694. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.5345144. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.5654595. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.5964043. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.6273494. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.6582944. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.6892395. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.7201843. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.7511294. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.7820745. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.8130193. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.8439643. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.8749094. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.9058542. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.9367993. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.9677444. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736701.9986892. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.0296342. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.0605793. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.0915244. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.1224692. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.1534142. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.1843593. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.2153041. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.2462492. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.2771943. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.308139. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.3390841. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.3700292. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.400974. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.431919. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.4628642. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.4938092. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.524754. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.555699. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.5866442. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.617589. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.648534. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.6794791. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.710424. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.741369. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.772314. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.803259. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.834204. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.865149. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.896094. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.927039. Shape = (0,)
# [Warning] Skipping invalid point cloud at t = 1758736702.957984. Shape = (0,)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as font_manager

# font
font = font_manager.FontProperties()
font.set_family('serif')
plt.rcParams.update({"text.usetex": True})
plt.rcParams["font.family"] = "Times New Roman"
font.set_size(60)

folder = "/home/kkondo/code/dynus_ws/src/dynus/paper_imgs"
save_folder = "/home/kkondo/paper_writing/DYNUS_v3/figures/sim/static_benchmark"

# ---- Crop parameters (pixels): top, bottom, left, right ----
CROP = {
    'hard_forest':   dict(top=300, bottom=300, left=500, right=150),
    'medium_forest': dict(top=300, bottom=300, left=400, right=250),
    'easy_forest':   dict(top=300, bottom=300, left=400, right=250),
}

def load_and_crop(name):
    img = plt.imread(f"{folder}/{name}.png")
    c = CROP[name]
    h, w = img.shape[:2]
    return img[c['top']: h - c['bottom'] if c['bottom'] else h,
               c['left']: w - c['right']  if c['right']  else w]

hard   = load_and_crop('hard_forest')
medium = load_and_crop('medium_forest')
easy   = load_and_crop('easy_forest')

# ---- Stack vertically ----
fig, axes = plt.subplots(3, 1, figsize=(14, 14 * 3 * hard.shape[0] / hard.shape[1]))

labels = ['Hard', 'Medium', 'Easy']
for ax, img, label in zip(axes, [hard, medium, easy], labels):
    ax.imshow(img)
    ax.text(0.03, 0.95, label, transform=ax.transAxes,
            fontsize=30, va='top', ha='left', color='black',
            bbox=dict(facecolor='white', alpha=0.5, edgecolor='none', boxstyle='round,pad=0.3'))
    ax.axis('off')

plt.tight_layout(pad=0.5)
plt.savefig(f"{save_folder}/stacked_forests.png", bbox_inches='tight', dpi=150)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as font_manager

# font
font = font_manager.FontProperties()
font.set_family('serif')
plt.rcParams.update({"text.usetex": True})
plt.rcParams["font.family"] = "Times New Roman"
font.set_size(60)

folder = "/home/kkondo/code/dynus_ws/src/dynus/paper_imgs"
save_folder = "/home/kkondo/paper_writing/DYNUS_v3/figures/sim/dynamic_benchmark"

# ---- Crop parameters (pixels): top, bottom, left, right ----
CROP = {
    'dynamic_hard':   dict(top=600, bottom=600, left=220, right=20),
    'dynamic_medium': dict(top=600, bottom=600, left=220, right=20),
    'dynamic_easy':   dict(top=600, bottom=600, left=220, right=20),
}

def load_and_crop(name):
    img = plt.imread(f"{folder}/{name}.png")
    c = CROP[name]
    h, w = img.shape[:2]
    return img[c['top']: h - c['bottom'] if c['bottom'] else h,
               c['left']: w - c['right']  if c['right']  else w]

hard   = load_and_crop('dynamic_hard')
medium = load_and_crop('dynamic_medium')
easy   = load_and_crop('dynamic_easy')

# ---- Stack vertically ----
fig, axes = plt.subplots(3, 1, figsize=(14, 14 * 3 * hard.shape[0] / hard.shape[1]))

labels = ['Hard', 'Medium', 'Easy']
for ax, img, label in zip(axes, [hard, medium, easy], labels):
    ax.imshow(img)
    ax.text(0.03, 0.95, label, transform=ax.transAxes,
            fontsize=30, va='top', ha='left', color='black',
            bbox=dict(facecolor='white', alpha=0.5, edgecolor='none', boxstyle='round,pad=0.3'))
    ax.axis('off')

plt.tight_layout(pad=0.5)
plt.savefig(f"{save_folder}/stacked_dynamic_env.png", bbox_inches='tight', dpi=150)
plt.show()
